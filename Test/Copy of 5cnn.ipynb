# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import matplotlib.pyplot as plt
import cv2
import numpy as np
import matplotlib.gridspec as gridspec
import seaborn as sns
import zlib
import itertools
import sklearn
import itertools
import scipy
import skimage
from skimage.transform import resize
import csv
from tqdm import tqdm
from sklearn import model_selection
from sklearn.model_selection import train_test_split, learning_curve,KFold,cross_val_score,StratifiedKFold
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix
import keras
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization
from keras.utils import np_utils
from keras.utils.np_utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
from keras import models, layers, optimizers
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.utils import class_weight
from keras.optimizers import SGD, RMSprop, Adam, Adagrad, Adadelta, RMSprop
from keras.models import Sequential, model_from_json
from keras.layers import Activation,Dense, Dropout, Flatten, Conv2D, MaxPool2D,MaxPooling2D,AveragePooling2D, BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint,Callback, EarlyStopping, ReduceLROnPlateau
from keras import backend as K
import tensorflow as tf
import pickle as pkl
from keras.layers import Dense
import pickle
from tqdm import tqdm
import random
random.seed(123)

# %%
with open("/content/drive/My Drive/Kaggle/train.pkl", "rb") as f1:
    x_train, y_train = pkl.load(f1)

# %%
with open("/content/drive/My Drive/Kaggle/test.pkl", "rb") as f2:
    x_test, y_test = pkl.load(f2)

# %%
with open("/content/drive/My Drive/Kaggle/val.pkl", "rb") as f3:
    x_val, y_val = pkl.load(f3)

# %%
batch_size=16
train_datagen = ImageDataGenerator(
        rescale=1.0/255,  
        height_shift_range= 0.05, 
        width_shift_range=0.1, 
        rotation_range=15,
        shear_range=0.2,
        zoom_range=0.1,
        horizontal_flip=True,fill_mode='nearest')
test_datagen = ImageDataGenerator(rescale=1.0/255)

# %%
train_batch = train_datagen.flow(x_train,y_train,batch_size=batch_size,shuffle=True)
test_batch = test_datagen.flow(x_test,y_test,batch_size=batch_size,shuffle=False)
val_batch = train_datagen.flow(x_val,y_val,batch_size=batch_size,shuffle=False)

# %%
file_path="/content/drive/My Drive/Colab Notebooks/best3h.hdf5"
llr=ReduceLROnPlateau(monitor='val_loss',factor=0.1,verbose=1, mode='auto',patience=5,min_delta=0.0001,min_lr=1e-6, cooldown=0)
checkpoint = ModelCheckpoint(file_path, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
early = EarlyStopping(monitor="val_loss", mode='auto', patience=10,restore_best_weights=True)
callbacks_list = [llr,checkpoint,early]

# %%
model5=Sequential()
model5.add(Conv2D(32,(3,3),activation='relu', input_shape=(128, 128, 3),padding='same'))
model5.add(BatchNormalization())
model5.add(MaxPooling2D((2, 2)))

model5.add(Conv2D(64,(3,3),activation='relu',padding='same'))
model5.add(BatchNormalization())
model5.add(MaxPooling2D((2, 2)))


model5.add(Conv2D(128,(3,3),activation='relu',padding='same'))
model5.add(BatchNormalization())
model5.add(MaxPooling2D((2, 2)))


model5.add(Conv2D(256,(3,3),activation='relu',padding='same'))
model5.add(BatchNormalization())
model5.add(MaxPooling2D((2, 2)))

model5.add(Conv2D(512,(3,3),activation='relu',padding='same'))
model5.add(BatchNormalization())
model5.add(MaxPooling2D((2, 2)))

model5.add(Flatten())
model5.add(Dense(512,activation='relu'))
model5.add(BatchNormalization())
model5.add(Dense(256,activation='relu'))
model5.add(Dropout(0.5))
model5.add(Dense(4,activation='softmax'))
model5.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 128, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 128, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 64, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 256)       1024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 512)         1180160
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 512)         2048
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               4194816
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 5,901,764
# Trainable params: 5,898,756
# Non-trainable params: 3,008
# _________________________________________________________________

# %%
model5.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.Adam(),metrics=['accuracy'])

# %%
history=model5.fit_generator(train_batch, validation_data=val_batch, epochs=100, validation_steps= x_val.shape[0] // batch_size, 
                       steps_per_epoch= x_train.shape[0] // batch_size, callbacks=[callbacks_list], verbose=1)
# Out:
# WARNING:tensorflow:From <ipython-input-11-4ff2171517af>:2: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.9893 - accuracy: 0.6147
# Epoch 00001: val_loss improved from inf to 1.37488, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 136s 79ms/step - loss: 0.9893 - accuracy: 0.6147 - val_loss: 1.3749 - val_accuracy: 0.4958
# Epoch 2/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.5513 - accuracy: 0.7989
# Epoch 00002: val_loss improved from 1.37488 to 0.77032, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 131s 76ms/step - loss: 0.5513 - accuracy: 0.7989 - val_loss: 0.7703 - val_accuracy: 0.7201
# Epoch 3/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.4644 - accuracy: 0.8368
# Epoch 00003: val_loss improved from 0.77032 to 0.55024, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 130s 75ms/step - loss: 0.4644 - accuracy: 0.8368 - val_loss: 0.5502 - val_accuracy: 0.7812
# Epoch 4/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.4413 - accuracy: 0.8479
# Epoch 00004: val_loss improved from 0.55024 to 0.47375, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 130s 75ms/step - loss: 0.4413 - accuracy: 0.8479 - val_loss: 0.4738 - val_accuracy: 0.8352
# Epoch 5/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.3880 - accuracy: 0.8678
# Epoch 00005: val_loss improved from 0.47375 to 0.38649, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 128s 74ms/step - loss: 0.3880 - accuracy: 0.8678 - val_loss: 0.3865 - val_accuracy: 0.8640
# Epoch 6/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.3751 - accuracy: 0.8753
# Epoch 00006: val_loss did not improve from 0.38649
# 1723/1723 [==============================] - 127s 74ms/step - loss: 0.3751 - accuracy: 0.8753 - val_loss: 0.5727 - val_accuracy: 0.8065
# Epoch 7/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.3464 - accuracy: 0.8859
# Epoch 00007: val_loss did not improve from 0.38649
# 1723/1723 [==============================] - 128s 74ms/step - loss: 0.3464 - accuracy: 0.8859 - val_loss: 0.3962 - val_accuracy: 0.8651
# Epoch 8/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.3317 - accuracy: 0.8883
# Epoch 00008: val_loss improved from 0.38649 to 0.34824, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 128s 74ms/step - loss: 0.3317 - accuracy: 0.8883 - val_loss: 0.3482 - val_accuracy: 0.8805
# Epoch 9/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.3209 - accuracy: 0.8944
# Epoch 00009: val_loss did not improve from 0.34824
# 1723/1723 [==============================] - 128s 74ms/step - loss: 0.3209 - accuracy: 0.8944 - val_loss: 0.3746 - val_accuracy: 0.8740
# Epoch 10/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.3020 - accuracy: 0.8997
# Epoch 00010: val_loss improved from 0.34824 to 0.30611, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 128s 74ms/step - loss: 0.3020 - accuracy: 0.8997 - val_loss: 0.3061 - val_accuracy: 0.8887
# Epoch 11/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.3022 - accuracy: 0.9029
# Epoch 00011: val_loss did not improve from 0.30611
# 1723/1723 [==============================] - 127s 74ms/step - loss: 0.3022 - accuracy: 0.9029 - val_loss: 0.3266 - val_accuracy: 0.8879
# Epoch 12/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.3051 - accuracy: 0.8992
# Epoch 00012: val_loss did not improve from 0.30611
# 1723/1723 [==============================] - 128s 74ms/step - loss: 0.3051 - accuracy: 0.8992 - val_loss: 0.3357 - val_accuracy: 0.8946
# Epoch 13/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2738 - accuracy: 0.9116
# Epoch 00013: val_loss improved from 0.30611 to 0.29380, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 128s 75ms/step - loss: 0.2738 - accuracy: 0.9116 - val_loss: 0.2938 - val_accuracy: 0.9023
# Epoch 14/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2660 - accuracy: 0.9140
# Epoch 00014: val_loss improved from 0.29380 to 0.28329, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 128s 74ms/step - loss: 0.2660 - accuracy: 0.9140 - val_loss: 0.2833 - val_accuracy: 0.9064
# Epoch 15/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2628 - accuracy: 0.9132
# Epoch 00015: val_loss improved from 0.28329 to 0.24745, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 129s 75ms/step - loss: 0.2628 - accuracy: 0.9132 - val_loss: 0.2475 - val_accuracy: 0.9195
# Epoch 16/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2538 - accuracy: 0.9177
# Epoch 00016: val_loss did not improve from 0.24745
# 1723/1723 [==============================] - 128s 74ms/step - loss: 0.2538 - accuracy: 0.9177 - val_loss: 0.2500 - val_accuracy: 0.9202
# Epoch 17/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2480 - accuracy: 0.9169
# Epoch 00017: val_loss did not improve from 0.24745
# 1723/1723 [==============================] - 128s 74ms/step - loss: 0.2480 - accuracy: 0.9169 - val_loss: 0.2716 - val_accuracy: 0.9086
# Epoch 18/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2386 - accuracy: 0.9209
# Epoch 00018: val_loss did not improve from 0.24745
# 1723/1723 [==============================] - 128s 74ms/step - loss: 0.2386 - accuracy: 0.9209 - val_loss: 0.2717 - val_accuracy: 0.9118
# Epoch 19/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2330 - accuracy: 0.9235
# Epoch 00019: val_loss improved from 0.24745 to 0.23486, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 129s 75ms/step - loss: 0.2330 - accuracy: 0.9235 - val_loss: 0.2349 - val_accuracy: 0.9234
# Epoch 20/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2629 - accuracy: 0.9125
# Epoch 00020: val_loss did not improve from 0.23486
# 1723/1723 [==============================] - 127s 74ms/step - loss: 0.2629 - accuracy: 0.9125 - val_loss: 0.2652 - val_accuracy: 0.9164
# Epoch 21/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2285 - accuracy: 0.9228
# Epoch 00021: val_loss did not improve from 0.23486
# 1723/1723 [==============================] - 127s 74ms/step - loss: 0.2285 - accuracy: 0.9228 - val_loss: 0.2825 - val_accuracy: 0.9145
# Epoch 22/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2251 - accuracy: 0.9251
# Epoch 00022: val_loss did not improve from 0.23486
# 1723/1723 [==============================] - 128s 74ms/step - loss: 0.2251 - accuracy: 0.9251 - val_loss: 0.2655 - val_accuracy: 0.9228
# Epoch 23/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2376 - accuracy: 0.9219
# Epoch 00023: val_loss improved from 0.23486 to 0.22565, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 129s 75ms/step - loss: 0.2376 - accuracy: 0.9219 - val_loss: 0.2257 - val_accuracy: 0.9251
# Epoch 24/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2196 - accuracy: 0.9266
# Epoch 00024: val_loss did not improve from 0.22565
# 1723/1723 [==============================] - 128s 74ms/step - loss: 0.2196 - accuracy: 0.9266 - val_loss: 0.2537 - val_accuracy: 0.9198
# Epoch 25/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2112 - accuracy: 0.9288
# Epoch 00025: val_loss did not improve from 0.22565
# 1723/1723 [==============================] - 127s 74ms/step - loss: 0.2112 - accuracy: 0.9288 - val_loss: 0.3256 - val_accuracy: 0.8969
# Epoch 26/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2219 - accuracy: 0.9255
# Epoch 00026: val_loss did not improve from 0.22565
# 1723/1723 [==============================] - 128s 74ms/step - loss: 0.2219 - accuracy: 0.9255 - val_loss: 0.2600 - val_accuracy: 0.9199
# Epoch 27/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2114 - accuracy: 0.9297
# Epoch 00027: val_loss did not improve from 0.22565
# 1723/1723 [==============================] - 127s 74ms/step - loss: 0.2114 - accuracy: 0.9297 - val_loss: 0.2479 - val_accuracy: 0.9196
# Epoch 28/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2037 - accuracy: 0.9321
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00028: val_loss did not improve from 0.22565
# 1723/1723 [==============================] - 128s 74ms/step - loss: 0.2037 - accuracy: 0.9321 - val_loss: 0.3712 - val_accuracy: 0.8724
# Epoch 29/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1846 - accuracy: 0.9379
# Epoch 00029: val_loss did not improve from 0.22565
# 1723/1723 [==============================] - 128s 74ms/step - loss: 0.1846 - accuracy: 0.9379 - val_loss: 0.2260 - val_accuracy: 0.9344
# Epoch 30/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1710 - accuracy: 0.9423
# Epoch 00030: val_loss improved from 0.22565 to 0.19511, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 129s 75ms/step - loss: 0.1710 - accuracy: 0.9423 - val_loss: 0.1951 - val_accuracy: 0.9350
# Epoch 31/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1662 - accuracy: 0.9442
# Epoch 00031: val_loss did not improve from 0.19511
# 1723/1723 [==============================] - 128s 74ms/step - loss: 0.1662 - accuracy: 0.9442 - val_loss: 0.2014 - val_accuracy: 0.9372
# Epoch 32/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1621 - accuracy: 0.9455
# Epoch 00032: val_loss improved from 0.19511 to 0.18594, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 128s 75ms/step - loss: 0.1621 - accuracy: 0.9455 - val_loss: 0.1859 - val_accuracy: 0.9378
# Epoch 33/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1569 - accuracy: 0.9467
# Epoch 00033: val_loss improved from 0.18594 to 0.18360, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 128s 74ms/step - loss: 0.1569 - accuracy: 0.9467 - val_loss: 0.1836 - val_accuracy: 0.9404
# Epoch 34/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1534 - accuracy: 0.9481
# Epoch 00034: val_loss did not improve from 0.18360
# 1723/1723 [==============================] - 128s 74ms/step - loss: 0.1534 - accuracy: 0.9481 - val_loss: 0.2186 - val_accuracy: 0.9347
# Epoch 35/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1500 - accuracy: 0.9491
# Epoch 00035: val_loss did not improve from 0.18360
# 1723/1723 [==============================] - 126s 73ms/step - loss: 0.1500 - accuracy: 0.9491 - val_loss: 0.1938 - val_accuracy: 0.9374
# Epoch 36/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1495 - accuracy: 0.9486
# Epoch 00036: val_loss improved from 0.18360 to 0.18347, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 127s 74ms/step - loss: 0.1495 - accuracy: 0.9486 - val_loss: 0.1835 - val_accuracy: 0.9382
# Epoch 37/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1465 - accuracy: 0.9512
# Epoch 00037: val_loss did not improve from 0.18347
# 1723/1723 [==============================] - 127s 73ms/step - loss: 0.1465 - accuracy: 0.9512 - val_loss: 0.1964 - val_accuracy: 0.9368
# Epoch 38/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1447 - accuracy: 0.9513
# Epoch 00038: val_loss did not improve from 0.18347
# 1723/1723 [==============================] - 126s 73ms/step - loss: 0.1447 - accuracy: 0.9513 - val_loss: 0.2129 - val_accuracy: 0.9391
# Epoch 39/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1420 - accuracy: 0.9519
# Epoch 00039: val_loss did not improve from 0.18347
# 1723/1723 [==============================] - 127s 73ms/step - loss: 0.1420 - accuracy: 0.9519 - val_loss: 0.2737 - val_accuracy: 0.9362
# Epoch 40/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1418 - accuracy: 0.9521
# Epoch 00040: val_loss did not improve from 0.18347
# 1723/1723 [==============================] - 127s 74ms/step - loss: 0.1418 - accuracy: 0.9521 - val_loss: 0.1983 - val_accuracy: 0.9426
# Epoch 41/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1413 - accuracy: 0.9523
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00041: val_loss did not improve from 0.18347
# 1723/1723 [==============================] - 127s 74ms/step - loss: 0.1413 - accuracy: 0.9523 - val_loss: 0.1934 - val_accuracy: 0.9401
# Epoch 42/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1363 - accuracy: 0.9528
# Epoch 00042: val_loss did not improve from 0.18347
# 1723/1723 [==============================] - 127s 74ms/step - loss: 0.1363 - accuracy: 0.9528 - val_loss: 0.1904 - val_accuracy: 0.9414
# Epoch 43/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1344 - accuracy: 0.9534
# Epoch 00043: val_loss did not improve from 0.18347
# 1723/1723 [==============================] - 127s 74ms/step - loss: 0.1344 - accuracy: 0.9534 - val_loss: 0.1952 - val_accuracy: 0.9410
# Epoch 44/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1364 - accuracy: 0.9542
# Epoch 00044: val_loss did not improve from 0.18347
# 1723/1723 [==============================] - 126s 73ms/step - loss: 0.1364 - accuracy: 0.9542 - val_loss: 0.1898 - val_accuracy: 0.9414
# Epoch 45/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1364 - accuracy: 0.9527
# Epoch 00045: val_loss improved from 0.18347 to 0.18085, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 127s 74ms/step - loss: 0.1364 - accuracy: 0.9527 - val_loss: 0.1808 - val_accuracy: 0.9411
# Epoch 46/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1360 - accuracy: 0.9531
# Epoch 00046: val_loss did not improve from 0.18085
# 1723/1723 [==============================] - 127s 74ms/step - loss: 0.1360 - accuracy: 0.9531 - val_loss: 0.1842 - val_accuracy: 0.9391
# Epoch 47/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1356 - accuracy: 0.9535
# Epoch 00047: val_loss improved from 0.18085 to 0.17876, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 127s 74ms/step - loss: 0.1356 - accuracy: 0.9535 - val_loss: 0.1788 - val_accuracy: 0.9426
# Epoch 48/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1349 - accuracy: 0.9532
# Epoch 00048: val_loss improved from 0.17876 to 0.17616, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 128s 74ms/step - loss: 0.1349 - accuracy: 0.9532 - val_loss: 0.1762 - val_accuracy: 0.9394
# Epoch 49/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1351 - accuracy: 0.9537
# Epoch 00049: val_loss did not improve from 0.17616
# 1723/1723 [==============================] - 126s 73ms/step - loss: 0.1351 - accuracy: 0.9537 - val_loss: 0.1878 - val_accuracy: 0.9414
# Epoch 50/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1320 - accuracy: 0.9547
# Epoch 00050: val_loss did not improve from 0.17616
# 1723/1723 [==============================] - 125s 73ms/step - loss: 0.1320 - accuracy: 0.9547 - val_loss: 0.1984 - val_accuracy: 0.9397
# Epoch 51/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1339 - accuracy: 0.9542
# Epoch 00051: val_loss did not improve from 0.17616
# 1723/1723 [==============================] - 126s 73ms/step - loss: 0.1339 - accuracy: 0.9542 - val_loss: 0.1848 - val_accuracy: 0.9387
# Epoch 52/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1320 - accuracy: 0.9545
# Epoch 00052: val_loss did not improve from 0.17616
# 1723/1723 [==============================] - 125s 73ms/step - loss: 0.1320 - accuracy: 0.9545 - val_loss: 0.1863 - val_accuracy: 0.9395
# Epoch 53/100
#  843/1723 [=============>................] - ETA: 53s - loss: 0.1347 - accuracy: 0.9546

# %%
def plot_learning_curve(history):
    plt.figure(figsize=(18,9))
    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.savefig('/content/drive/My Drive/Colab Notebooks/accuracy_curve3h.png')
    plt.subplot(1,2,2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.savefig('/content/drive/My Drive/Colab Notebooks/loss_curve3h.png')

# %%
plot_learning_curve(history)
plt.show()

# %%
model5.load_weights("/content/drive/My Drive/Colab Notebooks/best3h.hdf5")
score=model5.evaluate(test_batch)
print(score[1])

# %%
y_pred = model5.predict_generator(test_batch)
Y_pred = np.argmax(y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_true,Y_pred,target_names=['CNV','DME','DRUSEN','Normal']))

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.savefig('/content/drive/My Drive/Colab Notebooks/confusion5cnnh.png')

# %%
# confusion matrix
cm = confusion_matrix(Y_true, Y_pred)
 
print('--------------------')
print('| Confusion Matrix |')
print('--------------------')
print('\n {}'.format(cm))
        
# plot confusin matrix
plt.figure(figsize=(8,8))
plt.grid(b=False)
plot_confusion_matrix(cm, classes=['CNV','DME','DRUSEN','NORMAL'], normalize=False, 
                      title='Confusion matrix', cmap = plt.cm.Blues)
plt.show()

# %%
model_img_file = '/content/drive/My Drive/Colab Notebooks/5cnn2.png'
tf.keras.utils.plot_model(model5, to_file=model_img_file, show_shapes=True, show_layer_names=True)

# %%
model5.save('/content/drive/My Drive/Colab Notebooks/5cnn_model2.h5')
