# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import matplotlib.pyplot as plt
import cv2
import numpy as np
import matplotlib.gridspec as gridspec
import seaborn as sns
import zlib
import itertools
import sklearn
import itertools
import scipy
import skimage
from skimage.transform import resize
import csv
from tqdm import tqdm
from sklearn import model_selection
from sklearn.model_selection import train_test_split, learning_curve,KFold,cross_val_score,StratifiedKFold
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix
import keras
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization
from keras.utils import np_utils
from keras.utils.np_utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
from keras import models, layers, optimizers
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.utils import class_weight
from keras.optimizers import SGD, RMSprop, Adam, Adagrad, Adadelta, RMSprop
from keras.models import Sequential, model_from_json
from keras.layers import Activation,Dense, Dropout, Flatten, Conv2D, MaxPool2D,MaxPooling2D,AveragePooling2D, BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint,Callback, EarlyStopping, ReduceLROnPlateau
from keras import backend as K
import tensorflow as tf
import pickle as pkl
from keras.layers import Dense
import pickle
from tqdm import tqdm
import random
random.seed(123)

# %%
with open("/content/drive/My Drive/Kaggle/train.pkl", "rb") as f1:
    x_train, y_train = pkl.load(f1)

# %%
with open("/content/drive/My Drive/Kaggle/test.pkl", "rb") as f2:
    x_test, y_test = pkl.load(f2)

# %%
with open("/content/drive/My Drive/Kaggle/val.pkl", "rb") as f3:
    x_val, y_val = pkl.load(f3)

# %%
batch_size=16
train_datagen = ImageDataGenerator(
        rescale=1.0/255,  
        height_shift_range= 0.05, 
        width_shift_range=0.1, 
        rotation_range=15,
        shear_range=0.2,
        zoom_range=0.1,
        horizontal_flip=True,fill_mode='nearest')
test_datagen = ImageDataGenerator(rescale=1.0/255)

# %%
train_batch = train_datagen.flow(x_train,y_train,batch_size=batch_size,shuffle=True)
test_batch = test_datagen.flow(x_test,y_test,batch_size=batch_size,shuffle=False)
val_batch = train_datagen.flow(x_val,y_val,batch_size=batch_size,shuffle=False)

# %%
file_path="/content/drive/My Drive/Colab Notebooks/best3h.hdf5"
llr=ReduceLROnPlateau(monitor='val_loss',factor=0.1,verbose=1, mode='auto',patience=5,min_delta=0.0001,min_lr=1e-6, cooldown=0)
checkpoint = ModelCheckpoint(file_path, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
early = EarlyStopping(monitor="val_loss", mode='auto', patience=10,restore_best_weights=True)
callbacks_list = [llr,checkpoint,early]

# %%
model5=Sequential()
model5.add(Conv2D(32,(3,3),activation='relu', input_shape=(128, 128, 3),padding='same'))
model5.add(BatchNormalization())
model5.add(MaxPooling2D((2, 2)))

model5.add(Conv2D(64,(3,3),activation='relu',padding='same'))
model5.add(BatchNormalization())
model5.add(MaxPooling2D((2, 2)))


model5.add(Conv2D(128,(3,3),activation='relu',padding='same'))
model5.add(BatchNormalization())
model5.add(MaxPooling2D((2, 2)))


model5.add(Conv2D(256,(3,3),activation='relu',padding='same'))
model5.add(BatchNormalization())
model5.add(MaxPooling2D((2, 2)))

model5.add(Conv2D(512,(3,3),activation='relu',padding='same'))
model5.add(BatchNormalization())
model5.add(MaxPooling2D((2, 2)))

model5.add(Flatten())
model5.add(Dense(512,activation='relu'))
model5.add(BatchNormalization())
model5.add(Dense(256,activation='relu'))
model5.add(Dropout(0.5))
model5.add(Dense(4,activation='softmax'))
model5.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 128, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 128, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 64, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 256)       1024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 512)         1180160
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 512)         2048
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               4194816
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 5,901,764
# Trainable params: 5,898,756
# Non-trainable params: 3,008
# _________________________________________________________________

# %%
model5.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.Adam(),metrics=['accuracy'])

# %%
history=model5.fit_generator(train_batch, validation_data=val_batch, epochs=100, validation_steps= x_val.shape[0] // batch_size, 
                       steps_per_epoch= x_train.shape[0] // batch_size, callbacks=[callbacks_list], verbose=1)
# Out:
# WARNING:tensorflow:From <ipython-input-11-4ff2171517af>:2: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.9867 - accuracy: 0.6108
# Epoch 00001: val_loss improved from inf to 0.84722, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 133s 77ms/step - loss: 0.9867 - accuracy: 0.6108 - val_loss: 0.8472 - val_accuracy: 0.6593
# Epoch 2/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.5268 - accuracy: 0.8093
# Epoch 00002: val_loss did not improve from 0.84722
# 1723/1723 [==============================] - 128s 74ms/step - loss: 0.5268 - accuracy: 0.8093 - val_loss: 1.2265 - val_accuracy: 0.4496
# Epoch 3/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.4724 - accuracy: 0.8314
# Epoch 00003: val_loss improved from 0.84722 to 0.83832, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 128s 74ms/step - loss: 0.4724 - accuracy: 0.8314 - val_loss: 0.8383 - val_accuracy: 0.7217
# Epoch 4/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.4070 - accuracy: 0.8629
# Epoch 00004: val_loss improved from 0.83832 to 0.73092, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 128s 74ms/step - loss: 0.4070 - accuracy: 0.8629 - val_loss: 0.7309 - val_accuracy: 0.7564
# Epoch 5/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.3840 - accuracy: 0.8713
# Epoch 00005: val_loss improved from 0.73092 to 0.37942, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 126s 73ms/step - loss: 0.3840 - accuracy: 0.8713 - val_loss: 0.3794 - val_accuracy: 0.8746
# Epoch 6/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.3710 - accuracy: 0.8767
# Epoch 00006: val_loss improved from 0.37942 to 0.35136, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 128s 74ms/step - loss: 0.3710 - accuracy: 0.8767 - val_loss: 0.3514 - val_accuracy: 0.8859
# Epoch 7/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.3537 - accuracy: 0.8842
# Epoch 00007: val_loss did not improve from 0.35136
# 1723/1723 [==============================] - 125s 73ms/step - loss: 0.3537 - accuracy: 0.8842 - val_loss: 0.5978 - val_accuracy: 0.8017
# Epoch 8/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.3397 - accuracy: 0.8867
# Epoch 00008: val_loss did not improve from 0.35136
# 1723/1723 [==============================] - 125s 73ms/step - loss: 0.3397 - accuracy: 0.8867 - val_loss: 0.4379 - val_accuracy: 0.8581
# Epoch 9/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.3083 - accuracy: 0.8957
# Epoch 00009: val_loss improved from 0.35136 to 0.30853, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 126s 73ms/step - loss: 0.3083 - accuracy: 0.8957 - val_loss: 0.3085 - val_accuracy: 0.8974
# Epoch 10/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.3047 - accuracy: 0.9000
# Epoch 00010: val_loss did not improve from 0.30853
# 1723/1723 [==============================] - 128s 74ms/step - loss: 0.3047 - accuracy: 0.9000 - val_loss: 0.4005 - val_accuracy: 0.8547
# Epoch 11/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.3248 - accuracy: 0.8916
# Epoch 00011: val_loss improved from 0.30853 to 0.28067, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 128s 74ms/step - loss: 0.3248 - accuracy: 0.8916 - val_loss: 0.2807 - val_accuracy: 0.9036
# Epoch 12/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2826 - accuracy: 0.9057
# Epoch 00012: val_loss did not improve from 0.28067
# 1723/1723 [==============================] - 126s 73ms/step - loss: 0.2826 - accuracy: 0.9057 - val_loss: 0.2961 - val_accuracy: 0.9022
# Epoch 13/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2840 - accuracy: 0.9060
# Epoch 00013: val_loss did not improve from 0.28067
# 1723/1723 [==============================] - 124s 72ms/step - loss: 0.2840 - accuracy: 0.9060 - val_loss: 0.3518 - val_accuracy: 0.8897
# Epoch 14/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2732 - accuracy: 0.9111
# Epoch 00014: val_loss improved from 0.28067 to 0.26098, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 125s 72ms/step - loss: 0.2732 - accuracy: 0.9111 - val_loss: 0.2610 - val_accuracy: 0.9119
# Epoch 15/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2638 - accuracy: 0.9130
# Epoch 00015: val_loss did not improve from 0.26098
# 1723/1723 [==============================] - 124s 72ms/step - loss: 0.2638 - accuracy: 0.9130 - val_loss: 0.4738 - val_accuracy: 0.8512
# Epoch 16/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2578 - accuracy: 0.9158
# Epoch 00016: val_loss did not improve from 0.26098
# 1723/1723 [==============================] - 123s 71ms/step - loss: 0.2578 - accuracy: 0.9158 - val_loss: 0.4013 - val_accuracy: 0.9013
# Epoch 17/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2706 - accuracy: 0.9105
# Epoch 00017: val_loss did not improve from 0.26098
# 1723/1723 [==============================] - 124s 72ms/step - loss: 0.2706 - accuracy: 0.9105 - val_loss: 0.2615 - val_accuracy: 0.9119
# Epoch 18/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2397 - accuracy: 0.9220
# Epoch 00018: val_loss improved from 0.26098 to 0.24275, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 124s 72ms/step - loss: 0.2397 - accuracy: 0.9220 - val_loss: 0.2428 - val_accuracy: 0.9183
# Epoch 19/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2613 - accuracy: 0.9124
# Epoch 00019: val_loss did not improve from 0.24275
# 1723/1723 [==============================] - 123s 71ms/step - loss: 0.2613 - accuracy: 0.9124 - val_loss: 0.2642 - val_accuracy: 0.9083
# Epoch 20/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2343 - accuracy: 0.9204
# Epoch 00020: val_loss did not improve from 0.24275
# 1723/1723 [==============================] - 123s 71ms/step - loss: 0.2343 - accuracy: 0.9204 - val_loss: 0.3687 - val_accuracy: 0.9132
# Epoch 21/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2356 - accuracy: 0.9220
# Epoch 00021: val_loss did not improve from 0.24275
# 1723/1723 [==============================] - 123s 71ms/step - loss: 0.2356 - accuracy: 0.9220 - val_loss: 0.3412 - val_accuracy: 0.8911
# Epoch 22/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2344 - accuracy: 0.9231
# Epoch 00022: val_loss did not improve from 0.24275
# 1723/1723 [==============================] - 123s 71ms/step - loss: 0.2344 - accuracy: 0.9231 - val_loss: 0.2634 - val_accuracy: 0.9224
# Epoch 23/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.2351 - accuracy: 0.9214
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00023: val_loss did not improve from 0.24275
# 1723/1723 [==============================] - 123s 71ms/step - loss: 0.2351 - accuracy: 0.9214 - val_loss: 0.2620 - val_accuracy: 0.9199
# Epoch 24/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1912 - accuracy: 0.9361
# Epoch 00024: val_loss improved from 0.24275 to 0.22335, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 124s 72ms/step - loss: 0.1912 - accuracy: 0.9361 - val_loss: 0.2234 - val_accuracy: 0.9279
# Epoch 25/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1845 - accuracy: 0.9372
# Epoch 00025: val_loss improved from 0.22335 to 0.20714, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 124s 72ms/step - loss: 0.1845 - accuracy: 0.9372 - val_loss: 0.2071 - val_accuracy: 0.9352
# Epoch 26/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1767 - accuracy: 0.9414
# Epoch 00026: val_loss did not improve from 0.20714
# 1723/1723 [==============================] - 123s 72ms/step - loss: 0.1767 - accuracy: 0.9414 - val_loss: 0.2083 - val_accuracy: 0.9301
# Epoch 27/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1715 - accuracy: 0.9419
# Epoch 00027: val_loss improved from 0.20714 to 0.19247, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 124s 72ms/step - loss: 0.1715 - accuracy: 0.9419 - val_loss: 0.1925 - val_accuracy: 0.9362
# Epoch 28/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1700 - accuracy: 0.9426
# Epoch 00028: val_loss did not improve from 0.19247
# 1723/1723 [==============================] - 123s 71ms/step - loss: 0.1700 - accuracy: 0.9426 - val_loss: 0.2276 - val_accuracy: 0.9342
# Epoch 29/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1653 - accuracy: 0.9449
# Epoch 00029: val_loss did not improve from 0.19247
# 1723/1723 [==============================] - 123s 71ms/step - loss: 0.1653 - accuracy: 0.9449 - val_loss: 0.1990 - val_accuracy: 0.9365
# Epoch 30/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1641 - accuracy: 0.9437
# Epoch 00030: val_loss did not improve from 0.19247
# 1723/1723 [==============================] - 123s 72ms/step - loss: 0.1641 - accuracy: 0.9437 - val_loss: 0.1973 - val_accuracy: 0.9355
# Epoch 31/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1621 - accuracy: 0.9443
# Epoch 00031: val_loss did not improve from 0.19247
# 1723/1723 [==============================] - 123s 71ms/step - loss: 0.1621 - accuracy: 0.9443 - val_loss: 0.2020 - val_accuracy: 0.9342
# Epoch 32/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1613 - accuracy: 0.9443
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00032: val_loss did not improve from 0.19247
# 1723/1723 [==============================] - 123s 72ms/step - loss: 0.1613 - accuracy: 0.9443 - val_loss: 0.2122 - val_accuracy: 0.9356
# Epoch 33/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1591 - accuracy: 0.9460
# Epoch 00033: val_loss did not improve from 0.19247
# 1723/1723 [==============================] - 123s 72ms/step - loss: 0.1591 - accuracy: 0.9460 - val_loss: 0.1980 - val_accuracy: 0.9388
# Epoch 34/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1594 - accuracy: 0.9467
# Epoch 00034: val_loss did not improve from 0.19247
# 1723/1723 [==============================] - 123s 71ms/step - loss: 0.1594 - accuracy: 0.9467 - val_loss: 0.1992 - val_accuracy: 0.9353
# Epoch 35/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1546 - accuracy: 0.9466
# Epoch 00035: val_loss improved from 0.19247 to 0.18635, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 123s 71ms/step - loss: 0.1546 - accuracy: 0.9466 - val_loss: 0.1864 - val_accuracy: 0.9369
# Epoch 36/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1610 - accuracy: 0.9451
# Epoch 00036: val_loss did not improve from 0.18635
# 1723/1723 [==============================] - 122s 71ms/step - loss: 0.1610 - accuracy: 0.9451 - val_loss: 0.2344 - val_accuracy: 0.9391
# Epoch 37/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1518 - accuracy: 0.9488
# Epoch 00037: val_loss did not improve from 0.18635
# 1723/1723 [==============================] - 122s 71ms/step - loss: 0.1518 - accuracy: 0.9488 - val_loss: 0.2071 - val_accuracy: 0.9374
# Epoch 38/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1544 - accuracy: 0.9482
# Epoch 00038: val_loss did not improve from 0.18635
# 1723/1723 [==============================] - 122s 71ms/step - loss: 0.1544 - accuracy: 0.9482 - val_loss: 0.1985 - val_accuracy: 0.9375
# Epoch 39/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1509 - accuracy: 0.9480
# Epoch 00039: val_loss did not improve from 0.18635
# 1723/1723 [==============================] - 122s 71ms/step - loss: 0.1509 - accuracy: 0.9480 - val_loss: 0.1937 - val_accuracy: 0.9374
# Epoch 40/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1567 - accuracy: 0.9472
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00040: val_loss did not improve from 0.18635
# 1723/1723 [==============================] - 122s 71ms/step - loss: 0.1567 - accuracy: 0.9472 - val_loss: 0.1922 - val_accuracy: 0.9344
# Epoch 41/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1500 - accuracy: 0.9483
# Epoch 00041: val_loss did not improve from 0.18635
# 1723/1723 [==============================] - 122s 71ms/step - loss: 0.1500 - accuracy: 0.9483 - val_loss: 0.1949 - val_accuracy: 0.9390
# Epoch 42/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1549 - accuracy: 0.9471
# Epoch 00042: val_loss did not improve from 0.18635
# 1723/1723 [==============================] - 122s 71ms/step - loss: 0.1549 - accuracy: 0.9471 - val_loss: 0.1977 - val_accuracy: 0.9359
# Epoch 43/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1510 - accuracy: 0.9485
# Epoch 00043: val_loss improved from 0.18635 to 0.18377, saving model to /content/drive/My Drive/Colab Notebooks/best3h.hdf5
# 1723/1723 [==============================] - 123s 71ms/step - loss: 0.1510 - accuracy: 0.9485 - val_loss: 0.1838 - val_accuracy: 0.9356
# Epoch 44/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1554 - accuracy: 0.9472
# Epoch 00044: val_loss did not improve from 0.18377
# 1723/1723 [==============================] - 121s 70ms/step - loss: 0.1554 - accuracy: 0.9472 - val_loss: 0.1942 - val_accuracy: 0.9404
# Epoch 45/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1543 - accuracy: 0.9470
# Epoch 00045: val_loss did not improve from 0.18377
# 1723/1723 [==============================] - 122s 71ms/step - loss: 0.1543 - accuracy: 0.9470 - val_loss: 0.1907 - val_accuracy: 0.9358
# Epoch 46/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1559 - accuracy: 0.9475
# Epoch 00046: val_loss did not improve from 0.18377
# 1723/1723 [==============================] - 122s 71ms/step - loss: 0.1559 - accuracy: 0.9475 - val_loss: 0.1903 - val_accuracy: 0.9379
# Epoch 47/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1521 - accuracy: 0.9482
# Epoch 00047: val_loss did not improve from 0.18377
# 1723/1723 [==============================] - 122s 71ms/step - loss: 0.1521 - accuracy: 0.9482 - val_loss: 0.2097 - val_accuracy: 0.9347
# Epoch 48/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1523 - accuracy: 0.9490
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 00048: val_loss did not improve from 0.18377
# 1723/1723 [==============================] - 122s 71ms/step - loss: 0.1523 - accuracy: 0.9490 - val_loss: 0.1879 - val_accuracy: 0.9387
# Epoch 49/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1544 - accuracy: 0.9486
# Epoch 00049: val_loss did not improve from 0.18377
# 1723/1723 [==============================] - 125s 73ms/step - loss: 0.1544 - accuracy: 0.9486 - val_loss: 0.1897 - val_accuracy: 0.9376
# Epoch 50/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1533 - accuracy: 0.9469
# Epoch 00050: val_loss did not improve from 0.18377
# 1723/1723 [==============================] - 123s 71ms/step - loss: 0.1533 - accuracy: 0.9469 - val_loss: 0.2051 - val_accuracy: 0.9372
# Epoch 51/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1564 - accuracy: 0.9478
# Epoch 00051: val_loss did not improve from 0.18377
# 1723/1723 [==============================] - 122s 71ms/step - loss: 0.1564 - accuracy: 0.9478 - val_loss: 0.2050 - val_accuracy: 0.9384
# Epoch 52/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1491 - accuracy: 0.9473
# Epoch 00052: val_loss did not improve from 0.18377
# 1723/1723 [==============================] - 123s 71ms/step - loss: 0.1491 - accuracy: 0.9473 - val_loss: 0.2606 - val_accuracy: 0.9397
# Epoch 53/100
# 1723/1723 [==============================] - ETA: 0s - loss: 0.1542 - accuracy: 0.9480
# Epoch 00053: val_loss did not improve from 0.18377
# 1723/1723 [==============================] - 123s 71ms/step - loss: 0.1542 - accuracy: 0.9480 - val_loss: 0.2127 - val_accuracy: 0.9384

# %%
def plot_learning_curve(history):
    plt.figure(figsize=(18,9))
    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.savefig('/content/drive/My Drive/Colab Notebooks/accuracy_curve3h.png')
    plt.subplot(1,2,2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.savefig('/content/drive/My Drive/Colab Notebooks/loss_curve3h.png')

# %%
plot_learning_curve(history)
plt.show()

# %%
model5.load_weights("/content/drive/My Drive/Colab Notebooks/best3h.hdf5")
score=model5.evaluate(test_batch)
print(score[1])
# Out:
# 61/61 [==============================] - 0s 8ms/step - loss: 0.1360 - accuracy: 0.9824
# 0.9824380278587341

# %%
y_pred = model5.predict_generator(test_batch)
Y_pred = np.argmax(y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)
# Out:
# WARNING:tensorflow:From <ipython-input-15-9bd218eec3b1>:1: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_true,Y_pred,target_names=['CNV','DME','DRUSEN','Normal']))
# Out:
#               precision    recall  f1-score   support
#
#          CNV       0.94      1.00      0.97       242
#          DME       1.00      0.95      0.97       242
#       DRUSEN       1.00      0.98      0.99       242
#       Normal       1.00      1.00      1.00       242
#
#     accuracy                           0.98       968
#    macro avg       0.98      0.98      0.98       968
# weighted avg       0.98      0.98      0.98       968

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.savefig('/content/drive/My Drive/Colab Notebooks/confusion5cnnh.png')

# %%
# confusion matrix
cm = confusion_matrix(Y_true, Y_pred)
 
print('--------------------')
print('| Confusion Matrix |')
print('--------------------')
print('\n {}'.format(cm))
        
# plot confusin matrix
plt.figure(figsize=(8,8))
plt.grid(b=False)
plot_confusion_matrix(cm, classes=['CNV','DME','DRUSEN','NORMAL'], normalize=False, 
                      title='Confusion matrix', cmap = plt.cm.Blues)
plt.show()
# Out:
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[242   0   0   0]
#  [ 11 230   0   1]
#  [  4   0 238   0]
#  [  0   0   1 241]]

# %%
model_img_file = '/content/drive/My Drive/Colab Notebooks/5cnn2.png'
tf.keras.utils.plot_model(model5, to_file=model_img_file, show_shapes=True, show_layer_names=True)

# %%
model5.save('/content/drive/My Drive/Colab Notebooks/5cnn_model2.h5')
